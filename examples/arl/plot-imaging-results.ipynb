# %% [markdown]
# # Display the images resulting from test_imaging

# %%
# %matplotlib inline

import os
import sys

from matplotlib import pylab

pylab.rcParams['figure.figsize'] = (12.0, 12.0)
pylab.rcParams['image.cmap'] = 'rainbow'

import numpy
from matplotlib import pyplot as plt

from arl.data.parameters import arl_path
from arl.image.operations import show_image, qa_image, import_image_from_fits

import logging

log = logging.getLogger()
log.setLevel(logging.INFO)
log.addHandler(logging.StreamHandler(sys.stdout))

# %%
pylab.rcParams['figure.figsize'] = (12.0, 12.0)
pylab.rcParams['image.cmap'] = 'rainbow'


fits_files = []

results_dir = arl_path('tests/test_results')

for file in os.listdir(results_dir):
    if file.endswith("dirty.fits"):
        fits_files.append(file)
        
fits_files = numpy.sort(fits_files)

for file in fits_files:
    print('******************************************************************')

    im = import_image_from_fits('tests/test_results/%s' % file)
    print(qa_image(im, context=file))
    show_image(im, title=file)
    plt.show()
# Out:
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_2d_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.78976038965563
# 		min: -3.7022359462603838
# 		rms: 5.779901729103122
# 		sum: 1016.0582052615518
# 		medianabs: 0.9130876263123092
# 		median: -0.7575369532106153
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_2d_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.78976038965563
# 		min: -3.7022359462603838
# 		rms: 5.779901729103122
# 		sum: 1016.0582052615518
# 		medianabs: 0.9130876263123092
# 		median: -0.7575369532106153
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_2d_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.8191633562716
# 		min: -3.9326957331667014
# 		rms: 6.726259598760191
# 		sum: 706.2737407137158
# 		medianabs: 0.909128566924535
# 		median: -0.7562056590219868
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_2d_wprojection_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.8191633562716
# 		min: -3.9326957331667014
# 		rms: 6.726259598760191
# 		sum: 706.2737407137158
# 		medianabs: 0.909128566924535
# 		median: -0.7562056590219868
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.66407272394133
# 		min: -3.6791550034619704
# 		rms: 6.719068320036861
# 		sum: 818.3384589020486
# 		medianabs: 0.908223244517698
# 		median: -0.7721617772613282
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.66407272394133
# 		min: -3.6791550034619704
# 		rms: 6.719068320036861
# 		sum: 818.3384589020486
# 		medianabs: 0.908223244517698
# 		median: -0.7721617772613282
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_timeslice_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.31990340727954
# 		min: -3.7381877844148623
# 		rms: 5.650693797306556
# 		sum: 129.6447846208821
# 		medianabs: 0.9106720094304732
# 		median: -0.7510856065718274
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_timeslice_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 106.50005226831597
# 		min: -77.0140205129209
# 		rms: 3.559867665349793
# 		sum: 13676.924973929932
# 		medianabs: 0.4809023794184996
# 		median: -0.032449766378605416
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_timeslice_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.31990340727954
# 		min: -3.7381877844148623
# 		rms: 5.650693797306556
# 		sum: 129.6447846208821
# 		medianabs: 0.9106720094304732
# 		median: -0.7510856065718274
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.84284147386461
# 		min: -3.4811211961200272
# 		rms: 6.870763893113634
# 		sum: 790.1519560989216
# 		medianabs: 0.9062563330639328
# 		median: -0.7710145047795927
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wprojection_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.84284147386461
# 		min: -3.4811211961200272
# 		rms: 6.870763893113634
# 		sum: 790.1519560989216
# 		medianabs: 0.9062563330639328
# 		median: -0.7710145047795927
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wstack_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.31848639428874
# 		min: -3.732219264522134
# 		rms: 5.769691296646242
# 		sum: 1191.8592953552652
# 		medianabs: 0.9194108249887674
# 		median: -0.7543239007900321
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wstack_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 33.47323065440904
# 		min: -110.21854007560808
# 		rms: 4.265472463923797
# 		sum: 223.38432835768026
# 		medianabs: 0.4596074259478746
# 		median: 0.008622776696401213
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wstack_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.31848639428874
# 		min: -3.7229423377270376
# 		rms: 5.7720761663587
# 		sum: 961.8484498254575
# 		medianabs: 0.9197598813777383
# 		median: -0.7579295306361036
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.86908923525561
# 		min: -3.486824540321805
# 		rms: 6.850872806819178
# 		sum: 1905.7957410922045
# 		medianabs: 0.8779237571761402
# 		median: -0.7395150785029864
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 1.1880922912155256e-09
# 		min: -1.1127889720796702e-09
# 		rms: 4.305169377987595e-11
# 		sum: -1.057451972871764e-08
# 		medianabs: 3.135713910751292e-12
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.86908923525561
# 		min: -3.486824540321805
# 		rms: 6.850872806819178
# 		sum: 1905.7957410922045
# 		medianabs: 0.8779237571761402
# 		median: -0.7395150785029864
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.881924648265
# 		min: -3.486976090712062
# 		rms: 6.851398664438487
# 		sum: 1906.3995414997091
# 		medianabs: 0.8779253736478365
# 		median: -0.7396083569467784
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_wprojection_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 1.1879417449733864e-09
# 		min: -1.1126368715252966e-09
# 		rms: 4.305299901567977e-11
# 		sum: -1.0574504681588144e-08
# 		medianabs: 3.136310655627028e-12
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_wprojection_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.881924648265
# 		min: -3.486976090712062
# 		rms: 6.851398664438487
# 		sum: 1906.3995414997091
# 		medianabs: 0.8779253736478365
# 		median: -0.7396083569467784
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.80476588347389
# 		min: -4.492627650522075
# 		rms: 6.807160360318434
# 		sum: 737.2461464464764
# 		medianabs: 0.9331777478452763
# 		median: -0.7732147179666662
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.80476588347389
# 		min: -4.492627650522075
# 		rms: 6.807160360318434
# 		sum: 737.2461464464764
# 		medianabs: 0.9331777478452763
# 		median: -0.7732147179666662
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_spectral_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 118.11381060793012
# 		min: -3.470614019711148
# 		rms: 6.874476422845654
# 		sum: 821.082550664941
# 		medianabs: 0.9071873983304509
# 		median: -0.7721053833060637
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_spectral_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 118.11381060793012
# 		min: -3.470614019711148
# 		rms: 6.874476422845654
# 		sum: 821.082550664941
# 		medianabs: 0.9071873983304509
# 		median: -0.7721053833060637
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_spectral_pol_delayed_dirty.fits
# 	Data:
# 		shape: (1, 4, 256, 256)
# 		max: 118.11381060793012
# 		min: -11.81138106079301
# 		rms: 3.5222929221610944
# 		sum: 911.4016312380843
# 		medianabs: 0.11592494629204383
# 		median: -0.013168477020653994
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_spectral_pol_function_dirty.fits
# 	Data:
# 		shape: (1, 4, 256, 256)
# 		max: 118.11381060793012
# 		min: -11.81138106079301
# 		rms: 3.5222929221610944
# 		sum: 911.4016312380843
# 		medianabs: 0.11592494629204383
# 		median: -0.013168477020653994
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.98114849465034
# 		min: -3.6300617117990917
# 		rms: 6.872960530391005
# 		sum: 796.7972162483973
# 		medianabs: 0.9065717849552053
# 		median: -0.7704612068165583
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_wprojection_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.98114849465034
# 		min: -3.6300617117990917
# 		rms: 6.872960530391005
# 		sum: 796.7972162483973
# 		medianabs: 0.9065717849552053
# 		median: -0.7704612068165583
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_2d_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 31.275101089672187
# 		min: -108.09592965000114
# 		rms: 4.27194353830829
# 		sum: 183.85364889206858
# 		medianabs: 0.5182445031664553
# 		median: 0.021215286617807742
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_2d_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.0
# 		min: 0.0
# 		rms: 0.0
# 		sum: 0.0
# 		medianabs: 0.0
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_2d_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.5664518974083703
# 		min: -0.6210883691994336
# 		rms: 0.05976917223284391
# 		sum: -32.91766332594371
# 		medianabs: 0.03720254455044558
# 		median: -0.0008267130175754118
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_2d_wprojection_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.0
# 		min: 0.0
# 		rms: 0.0
# 		sum: 0.0
# 		medianabs: 0.0
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_facets_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 36.87562419112811
# 		min: -31.62723506362442
# 		rms: 1.254451441652796
# 		sum: -46.35164742932655
# 		medianabs: 0.195724169923077
# 		median: -0.004094244609929538
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_facets_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.0
# 		min: 0.0
# 		rms: 0.0
# 		sum: 0.0
# 		medianabs: 0.0
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_facets_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.5113644392934813
# 		min: -0.3222281270473054
# 		rms: 0.06886977636165148
# 		sum: -0.2737927015586479
# 		medianabs: 0.04496640884587558
# 		median: -0.0002916352954758508
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_facets_wprojection_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.0
# 		min: 0.0
# 		rms: 0.0
# 		sum: 0.0
# 		medianabs: 0.0
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_timeslice_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 9.531880299240015
# 		min: -45.74150471358572
# 		rms: 1.1515451855315664
# 		sum: 11.383015884168344
# 		medianabs: 0.16349945995382628
# 		median: 0.0612411917634794
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_timeslice_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.0
# 		min: 0.0
# 		rms: 0.0
# 		sum: 0.0
# 		medianabs: 0.0
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_timeslice_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 9.528622225011956
# 		min: -45.75966179338058
# 		rms: 1.1518424891938865
# 		sum: 11.44135214489927
# 		medianabs: 0.16358189587246064
# 		median: 0.061381788824277084
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_timeslice_wprojection_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.0
# 		min: 0.0
# 		rms: 0.0
# 		sum: 0.0
# 		medianabs: 0.0
# 		median: 0.0
