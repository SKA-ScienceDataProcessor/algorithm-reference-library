# %% [markdown]
# # Display the images resulting from test_imaging

# %%
# %matplotlib inline

import os
import sys

from matplotlib import pylab

pylab.rcParams['figure.figsize'] = (12.0, 12.0)
pylab.rcParams['image.cmap'] = 'rainbow'

import numpy
from matplotlib import pyplot as plt

from arl.data.parameters import arl_path
from arl.image.operations import show_image, qa_image, import_image_from_fits

import logging

log = logging.getLogger()
log.setLevel(logging.INFO)
log.addHandler(logging.StreamHandler(sys.stdout))

# %%
pylab.rcParams['figure.figsize'] = (12.0, 12.0)
pylab.rcParams['image.cmap'] = 'rainbow'


fits_files = []

results_dir = arl_path('tests/test_results')

for file in os.listdir(results_dir):
    if file.endswith("dirty.fits"):
        fits_files.append(file)
        
fits_files = numpy.sort(fits_files)

for file in fits_files:
    print('******************************************************************')

    im = import_image_from_fits('tests/test_results/%s' % file)
    print(qa_image(im, context=file))
    show_image(im, title=file)
    plt.show()
# Out:
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_2d_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.78976038965563
# 		min: -3.7022359462603838
# 		rms: 5.779901729103122
# 		sum: 1016.0582052615518
# 		medianabs: 0.9130876263123092
# 		median: -0.7575369532106153
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_2d_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.78976038965563
# 		min: -3.7022359462603838
# 		rms: 5.779901729103122
# 		sum: 1016.0582052615518
# 		medianabs: 0.9130876263123092
# 		median: -0.7575369532106153
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_2d_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.8191633562716
# 		min: -3.9326957331667014
# 		rms: 6.726259598760191
# 		sum: 706.2737407137158
# 		medianabs: 0.909128566924535
# 		median: -0.7562056590219868
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_2d_wprojection_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.8191633562716
# 		min: -3.9326957331667014
# 		rms: 6.726259598760191
# 		sum: 706.2737407137158
# 		medianabs: 0.909128566924535
# 		median: -0.7562056590219868
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.66407272394133
# 		min: -3.6791550034619704
# 		rms: 6.719068320036861
# 		sum: 818.3384589020486
# 		medianabs: 0.908223244517698
# 		median: -0.7721617772613282
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.66407272394133
# 		min: -3.6791550034619704
# 		rms: 6.719068320036861
# 		sum: 818.3384589020486
# 		medianabs: 0.908223244517698
# 		median: -0.7721617772613282
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_timeslice_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.31990340727954
# 		min: -3.8022018418026153
# 		rms: 5.672875544632077
# 		sum: 496.16350052950565
# 		medianabs: 0.906941095278342
# 		median: -0.7479725653594507
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_timeslice_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 9.67927211099692
# 		min: -22.070499112939483
# 		rms: 0.49799564209511604
# 		sum: -608.6109771931044
# 		medianabs: 6.106226635438361e-16
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_timeslice_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.31990340727954
# 		min: -3.8022018418026153
# 		rms: 5.672875544632077
# 		sum: 496.16350052950565
# 		medianabs: 0.906941095278342
# 		median: -0.7479725653594507
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.8191633562716
# 		min: -3.9326957331667014
# 		rms: 6.726259598760191
# 		sum: 706.2737407137158
# 		medianabs: 0.909128566924535
# 		median: -0.7562056590219868
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wprojection_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.8191633562716
# 		min: -3.9326957331667014
# 		rms: 6.726259598760191
# 		sum: 706.2737407137158
# 		medianabs: 0.909128566924535
# 		median: -0.7562056590219868
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wstack_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.30877886397349
# 		min: -4.941969458546579
# 		rms: 5.743063560491809
# 		sum: 1313.3111841196178
# 		medianabs: 0.9374190748852977
# 		median: -0.7425397025822718
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wstack_difference_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 7.6425787827416976
# 		min: -94.55299052297175
# 		rms: 0.7707376424642346
# 		sum: -336.9277358074936
# 		medianabs: 1.6653345369377348e-16
# 		median: 0.0
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_facets_wstack_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.30877886397349
# 		min: -4.941969458546579
# 		rms: 5.743063560491809
# 		sum: 1313.3111841196178
# 		medianabs: 0.9374190748852977
# 		median: -0.7425397025822718
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.86908923525561
# 		min: -3.486824540321805
# 		rms: 6.850872806819178
# 		sum: 1905.7957410922045
# 		medianabs: 0.8779237571761402
# 		median: -0.7395150785029864
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.86908923525561
# 		min: -3.486824540321805
# 		rms: 6.850872806819178
# 		sum: 1905.7957410922045
# 		medianabs: 0.8779237571761402
# 		median: -0.7395150785029864
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.881924648265
# 		min: -3.486976090712062
# 		rms: 6.851398664438487
# 		sum: 1906.3995414997091
# 		medianabs: 0.8779253736478365
# 		median: -0.7396083569467784
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_timeslice_wprojection_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.881924648265
# 		min: -3.486976090712062
# 		rms: 6.851398664438487
# 		sum: 1906.3995414997091
# 		medianabs: 0.8779253736478365
# 		median: -0.7396083569467784
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.80476588347389
# 		min: -4.492627650522075
# 		rms: 6.807160360318434
# 		sum: 737.2461464464764
# 		medianabs: 0.9331777478452763
# 		median: -0.7732147179666662
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.80476588347389
# 		min: -4.492627650522075
# 		rms: 6.807160360318434
# 		sum: 737.2461464464764
# 		medianabs: 0.9331777478452763
# 		median: -0.7732147179666662
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_spectral_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.80476588347389
# 		min: -4.492627650522075
# 		rms: 6.807160360318434
# 		sum: 737.2461464464764
# 		medianabs: 0.9331777478452763
# 		median: -0.7732147179666662
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_spectral_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 116.80476588347389
# 		min: -4.492627650522075
# 		rms: 6.807160360318434
# 		sum: 737.2461464464764
# 		medianabs: 0.9331777478452763
# 		median: -0.7732147179666662
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_spectral_pol_delayed_dirty.fits
# 	Data:
# 		shape: (1, 4, 256, 256)
# 		max: 116.80476588347389
# 		min: -11.680476588347389
# 		rms: 3.48780129283137
# 		sum: 818.3432225555888
# 		medianabs: 0.11941151108629805
# 		median: -0.013135851141095004
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_spectral_pol_function_dirty.fits
# 	Data:
# 		shape: (1, 4, 256, 256)
# 		max: 116.80476588347389
# 		min: -11.680476588347389
# 		rms: 3.48780129283137
# 		sum: 818.3432225555888
# 		medianabs: 0.11941151108629805
# 		median: -0.013135851141095004
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.18994270925937
# 		min: -3.568277660575308
# 		rms: 6.769820948204659
# 		sum: 877.4575881626538
# 		medianabs: 0.9056848782672038
# 		median: -0.7590862057744182
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_invert_wstack_wprojection_function_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 117.18994270925937
# 		min: -3.568277660575308
# 		rms: 6.769820948204659
# 		sum: 877.4575881626538
# 		medianabs: 0.9056848782672038
# 		median: -0.7590862057744182
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_2d_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.15078584876165754
# 		min: -0.1898709987424664
# 		rms: 0.03533783036043013
# 		sum: -42.59861479824749
# 		medianabs: 0.023457397146245194
# 		median: -0.0007837595169702836
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_2d_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.614382666980076
# 		min: -0.7573938213981622
# 		rms: 0.09848772793463899
# 		sum: -80.17781032148409
# 		medianabs: 0.05855490311651004
# 		median: -0.0011249850690469576
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_facets_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 36.87562419112811
# 		min: -31.62723506362442
# 		rms: 1.254451441652796
# 		sum: -46.35164742932655
# 		medianabs: 0.195724169923077
# 		median: -0.004094244609929538
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_facets_timeslice_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 101.90716597906933
# 		min: -5.384088084700851
# 		rms: 4.883042666155688
# 		sum: -814.4654964487845
# 		medianabs: 0.745590274392891
# 		median: -0.6281509648448629
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_facets_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 0.6205320208814256
# 		min: -0.32523073564853944
# 		rms: 0.07142526218632875
# 		sum: -5.4042077150858745
# 		medianabs: 0.045966804929904584
# 		median: -0.0007132912187195077
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_facets_wstack_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 1.1825760792128792
# 		min: -1.0804646493970897
# 		rms: 0.12419854777703897
# 		sum: -23.44317548500612
# 		medianabs: 0.05899629035370428
# 		median: -0.002458559750059898
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_timeslice_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 9.531880299240015
# 		min: -45.74150471358572
# 		rms: 1.1515451855315664
# 		sum: 11.383015884168344
# 		medianabs: 0.16349945995382628
# 		median: 0.0612411917634794
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_timeslice_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 9.528622225011956
# 		min: -45.75966179338058
# 		rms: 1.1518424891938865
# 		sum: 11.44135214489927
# 		medianabs: 0.16358189587246064
# 		median: 0.061381788824277084
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_wstack_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 1.5959862983113007
# 		min: -1.864027632535625
# 		rms: 0.14209214808970402
# 		sum: 61.433071481810344
# 		medianabs: 0.059766301358701535
# 		median: 0.0035809780941495743
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_wstack_spectral_delayed_dirty.fits
# 	Data:
# 		shape: (1, 4, 256, 256)
# 		max: 3.0719343012451006
# 		min: -3.7793245933093784
# 		rms: 0.1948705225558018
# 		sum: -398.372678663945
# 		medianabs: 0.014614131951361041
# 		median: 0.00010243140872941488
# ******************************************************************
# Quality assessment:
# 	Origin: qa_image
# 	Context: test_imaging_predict_wstack_wprojection_delayed_dirty.fits
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 2.108764208501377
# 		min: -2.5595325222084293
# 		rms: 0.2558807233668587
# 		sum: -289.63216517511273
# 		medianabs: 0.08810251251181739
# 		median: 0.004055072539999891
